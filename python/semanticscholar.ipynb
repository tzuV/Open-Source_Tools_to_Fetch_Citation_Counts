# %% [markdown]
# # semanticscholar
# link: https://github.com/danielnsilva/semanticscholar/

# %%
# !pip install semanticscholar

# %%
# First, import the client from semanticscholar module
from semanticscholar import SemanticScholar

# You'll need an instance of the client to request data from the API
sch = SemanticScholar()

# Get a paper by its ID
paper = sch.get_paper('10.1093/mind/lix.236.433')

# Print the paper title
print(paper.title)
# Out:
# ---------------------------------------------------------------------------
# InternalServerErrorException              Traceback (most recent call last)
# Cell In[7], line 8
#       5 sch = SemanticScholar()
#       7 # Get a paper by its ID
# ----> 8 paper = sch.get_paper('10.1093/mind/lix.236.433')
#      10 # Print the paper title
#      11 print(paper.title)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\semanticscholar\SemanticScholar.py:127, in SemanticScholar.get_paper(self, paper_id, fields)
#     104 '''
#     105 Paper lookup
#     106
#    (...)
#     123 :raises: ObjectNotFoundException: if Paper ID not found.
#     124 '''
#     126 loop = asyncio.get_event_loop()
# --> 127 paper = loop.run_until_complete(
#     128     self._AsyncSemanticScholar.get_paper(
#     129         paper_id=paper_id,
#     130         fields=fields
#     131         )
#     132 )
#     134 return paper
#
# ...

# %%
# First, import the client from semanticscholar module
from semanticscholar import SemanticScholar

# You'll need an instance of the client to request data from the API
sch = SemanticScholar()

# Get a paper by its ID
paper = sch.get_paper('10.48550/arXiv.1706.03762')

# Print the paper title
print(paper.title)
# Out:
# ---------------------------------------------------------------------------
# ObjectNotFoundException                   Traceback (most recent call last)
# Cell In[5], line 8
#       5 sch = SemanticScholar()
#       7 # Get a paper by its ID
# ----> 8 paper = sch.get_paper('10.48550/arXiv.1706.03762')
#      10 # Print the paper title
#      11 print(paper.title)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\semanticscholar\SemanticScholar.py:127, in SemanticScholar.get_paper(self, paper_id, fields)
#     104 '''
#     105 Paper lookup
#     106
#    (...)
#     123 :raises: ObjectNotFoundException: if Paper ID not found.
#     124 '''
#     126 loop = asyncio.get_event_loop()
# --> 127 paper = loop.run_until_complete(
#     128     self._AsyncSemanticScholar.get_paper(
#     129         paper_id=paper_id,
#     130         fields=fields
#     131         )
#     132 )
#     134 return paper
#
# ...
